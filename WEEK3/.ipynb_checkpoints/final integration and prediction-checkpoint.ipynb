# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
# Load merged dataset (THIS WAS MISSING)
df = pd.read_csv("WEEK3_dataset.csv")

print(df.shape)
print(df.columns)
df.head()

# Target: next-day return
df['target'] = df['return'].shift(-1)

# Drop last row (target becomes NaN)
df = df.dropna().reset_index(drop=True)
features = [
    'sentiment_lag1',
    'sentiment_3d',
    'sentiment_7d',
    'volatility_5d'
]

X = df[features].values
y = df['target'].values
assert 'target' in df.columns
assert not np.isnan(X).any()
assert not np.isnan(y).any()
print("Dataset ready for LSTM 🚀")
# Out:
# (0, 12)
# Index(['date', 'Close', 'High', 'Low', 'Open', 'Volume', 'avg_sentiment',
#        'return', 'volatility_5d', 'sentiment_lag1', 'sentiment_3d',
#        'sentiment_7d'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 28
#      26 y = df['target'].values
#      27 assert 'target' in df.columns
# ---> 28 assert not np.isnan(X).any()
#      29 assert not np.isnan(y).any()
#      30 print("Dataset ready for LSTM 🚀")
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Target: next-day return
df['target'] = df['return'].shift(-1)

# Drop last row (target becomes NaN)
df = df.dropna().reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Target: next-day return
# ----> 2 df['target'] = df['return'].shift(-1)
#       4 # Drop last row (target becomes NaN)
#       5 df = df.dropna().reset_index(drop=True)
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

features = [
    'sentiment',
    'sentiment_lag1',
    'sentiment_lag2',
    'volatility'
]

X = df[features]
y = df['target']

# Time-based split (80% train, 20% test)
split_idx = int(0.8 * len(df))
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print(f"RMSE: {rmse:.6f}")
print(f"MAE : {mae:.6f}")

# %%
coefficients = pd.DataFrame({
    'Feature': features,
    'Coefficient': model.coef_
}).sort_values(by='Coefficient', key=abs, ascending=False)

print(coefficients)
